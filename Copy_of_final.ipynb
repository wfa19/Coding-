# %% [markdown]
# <a href="https://colab.research.google.com/github/wfa19/Coding-/blob/main/Copy_of_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#    Country   Age   Salary Purchase Date of birth
# 0   France  44.0  72000.0       No    1989-12-05
# 1    Spain  38.0  61000.0       No    2002-10-10
# 2  Germany  30.0  54000.0       No    1998-05-12
# 3    Spain  38.0  61000.0       No    2002-10-10
# 4  Germany  40.0      NaN      Yes    1995-12-25
# 5   France  35.0  58000.0      Yes    1988-11-28
# 6    Spain   NaN  52000.0       No      19990903
# 7   France  48.0  79000.0      Yes    1992-03-03
# 8  Germany  50.0  83000.0       No      19820619
# 9   France  37.0  67000.0      Yes      19941208

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country        10 non-null     object
#  1   Age            9 non-null      float64
#  2   Salary         9 non-null      float64
#  3   Purchase       10 non-null     object
#  4   Date of birth  10 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 528.0+ bytes

# %%
df
# Out:
#    Country   Age   Salary Purchase Date of birth
# 0   France  44.0  72000.0       No    1989-12-05
# 1    Spain  38.0  61000.0       No    2002-10-10
# 2  Germany  30.0  54000.0       No    1998-05-12
# 3    Spain  38.0  61000.0       No    2002-10-10
# 4  Germany  40.0      NaN      Yes    1995-12-25
# 5   France  35.0  58000.0      Yes    1988-11-28
# 6    Spain   NaN  52000.0       No      19990903
# 7   France  48.0  79000.0      Yes    1992-03-03
# 8  Germany  50.0  83000.0       No      19820619
# 9   France  37.0  67000.0      Yes      19941208

# %%
df["Salary"].fillna(50000, inplace = True) #Replace NULL values in the "Salary" columns with the number 50000
print(df.to_string())
# Out:
#    Country   Age   Salary Purchase Date of birth
# 0   France  44.0  72000.0       No    1989-12-05
# 1    Spain  38.0  61000.0       No    2002-10-10
# 2  Germany  30.0  54000.0       No    1998-05-12
# 3    Spain  38.0  61000.0       No    2002-10-10
# 4  Germany  40.0  50000.0      Yes    1995-12-25
# 5   France  35.0  58000.0      Yes    1988-11-28
# 6    Spain   NaN  52000.0       No      19990903
# 7   France  48.0  79000.0      Yes    1992-03-03
# 8  Germany  50.0  83000.0       No      19820619
# 9   France  37.0  67000.0      Yes      19941208

# %%
df[["Age","Salary"]].mean()
# Out:
# Age          40.0
# Salary    63700.0
# dtype: float64

# %%
df['Date of birth'] = pd.to_datetime(df['Date of birth'])

print(df.to_string())
# Out:
#    Country   Age   Salary Purchase Date of birth
# 0   France  44.0  72000.0       No    1989-12-05
# 1    Spain  38.0  61000.0       No    2002-10-10
# 2  Germany  30.0  54000.0       No    1998-05-12
# 3    Spain  38.0  61000.0       No    2002-10-10
# 4  Germany  40.0  50000.0      Yes    1995-12-25
# 5   France  35.0  58000.0      Yes    1988-11-28
# 6    Spain   NaN  52000.0       No    1999-09-03
# 7   France  48.0  79000.0      Yes    1992-03-03
# 8  Germany  50.0  83000.0       No    1982-06-19
# 9   France  37.0  67000.0      Yes    1994-12-08

# %%
df[["Age","Salary"]].describe()
# Out:
#              Age        Salary
# count   9.000000     10.000000
# mean   40.000000  63700.000000
# std     6.344289  11314.199535
# min    30.000000  50000.000000
# 25%    37.000000  55000.000000
# 50%    38.000000  61000.000000
# 75%    44.000000  70750.000000
# max    50.000000  83000.000000

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df
# Out:
#    Country   Age   Salary Purchase Date of birth
# 0   France  44.0  72000.0       No    1989-12-05
# 1    Spain  38.0  61000.0       No    2002-10-10
# 2  Germany  30.0  54000.0       No    1998-05-12
# 3    Spain  38.0  61000.0       No    2002-10-10
# 4  Germany  40.0  50000.0      Yes    1995-12-25
# 5   France  35.0  58000.0      Yes    1988-11-28
# 6    Spain   NaN  52000.0       No    1999-09-03
# 7   France  48.0  79000.0      Yes    1992-03-03
# 8  Germany  50.0  83000.0       No    1982-06-19
# 9   France  37.0  67000.0      Yes    1994-12-08

# %%
x = df["Age"].median()  #Calculate the median, and replace any empty values with it.
df["Age"].fillna(x, inplace = True)
print(df.to_string())
# Out:
#    Country   Age   Salary Purchase Date of birth
# 0   France  44.0  72000.0       No    1989-12-05
# 1    Spain  38.0  61000.0       No    2002-10-10
# 2  Germany  30.0  54000.0       No    1998-05-12
# 3    Spain  38.0  61000.0       No    2002-10-10
# 4  Germany  40.0  50000.0      Yes    1995-12-25
# 5   France  35.0  58000.0      Yes    1988-11-28
# 6    Spain  38.0  52000.0       No    1999-09-03
# 7   France  48.0  79000.0      Yes    1992-03-03
# 8  Germany  50.0  83000.0       No    1982-06-19
# 9   France  37.0  67000.0      Yes    1994-12-08

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
new_df = df.dropna()              #Return a new Data Frame with no empty cells.

print(new_df.to_string())
print(new_df.to_string())
# Out:
#    Country   Age   Salary Purchase Date of birth
# 0   France  44.0  72000.0       No    1989-12-05
# 1    Spain  38.0  61000.0       No    2002-10-10
# 2  Germany  30.0  54000.0       No    1998-05-12
# 3    Spain  38.0  61000.0       No    2002-10-10
# 4  Germany  40.0  50000.0      Yes    1995-12-25
# 5   France  35.0  58000.0      Yes    1988-11-28
# 6    Spain  38.0  52000.0       No    1999-09-03
# 7   France  48.0  79000.0      Yes    1992-03-03
# 8  Germany  50.0  83000.0       No    1982-06-19
# 9   France  37.0  67000.0      Yes    1994-12-08
#    Country   Age   Salary Purchase Date of birth
# 0   France  44.0  72000.0       No    1989-12-05
# 1    Spain  38.0  61000.0       No    2002-10-10
# 2  Germany  30.0  54000.0       No    1998-05-12
# 3    Spain  38.0  61000.0       No    2002-10-10
# 4  Germany  40.0  50000.0      Yes    1995-12-25
# 5   France  35.0  58000.0      Yes    1988-11-28
# 6    Spain  38.0  52000.0       No    1999-09-03
# ...

# %%
# Create a sample dataframe with categorical data and target
df = pd.DataFrame({'Country': ['France', 'Spain', 'Germany',],
                   'target': [0, 1, 0]})
print(f"Before Encoding the Data:\n\n{df}\n")

# Calculate the mean target value for each category
target_mean = df.groupby('Country')['target'].mean()

# Replace the categorical data with the mean target value
df['Country_label'] = df['Country'].map(target_mean)


print(f"After Encoding the Data:\n\n{df}")
# Out:
# Before Encoding the Data:
#
#    Country  target
# 0   France       0
# 1    Spain       1
# 2  Germany       0
#
# After Encoding the Data:
#
#    Country  target  Country_label
# 0   France       0            0.0
# 1    Spain       1            1.0
# 2  Germany       0            0.0

# %%
df
# Out:
#    Country  target  Country_label
# 0   France       0            0.0
# 1    Spain       1            1.0
# 2  Germany       0            0.0
